# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
sparSession = SparkSession.builder.appName("MarketSales Spark Analysis").getOrCreate()

# %%
rawDF = sparSession.read.option("delimiter",";").csv("/FileStore/tables/MarketSales_20220215-2.csv",header=True, inferSchema=True).drop("SALESMAN","CLİENTNAME")

# %%
rawDF.describe().show()
# Out:
# +-------+--------------------+--------------------+--------------+------------------+-----------------+-----------------+------------------+-------------+------+----------+------------------+------------------+----------+--------------+---------------+-----------------+--------------+--------------+------+
# |summary|                  ID|            ITEMNAME|         DATE_|            AMOUNT|            PRICE|     LINENETTOTAL|          BRANCHNR|       BRANCH|  CITY|    REGION|        CLIENTCODE|         BRANDCODE|     BRAND|CATEGORY_NAME1| CATEGORY_NAME2|   CATEGORY_NAME3|     STARTDATE|       ENDDATE|GENDER|
# +-------+--------------------+--------------------+--------------+------------------+-----------------+-----------------+------------------+-------------+------+----------+------------------+------------------+----------+--------------+---------------+-----------------+--------------+--------------+------+
# |  count|              611115|              603941|        611099|            611099|           611099|           611099|            611099|       611099|611099|    611099|            592752|            575543|    575543|        603933|         583440|           401643|        611100|        611100|592735|
# |   mean|   306846.2916641439|                null|          null| 1.270207542476749|3.959491260827359| 4.05565945943332| 39.20164163253417|         null|  null|      null|510501.26827334304|142.66605404064418|      null|          null|           null|             null|          null|          null|  null|
# | stddev|   181259.6857125472|                null|          null|1.9953139983230577|6.683080725148242|11.95612107715333|21.827232654862016|         null|  null|      null| 337215.2970231874| 90.77806800282771|      null|          null|           null|             null|          null|          null|  null|
# |    min|                   1|8*4 150 ML DEO D�...|01/02/17 00:00|             0.001|             0.01|             0.01|                 1| Adana Subesi| Adana|   Akdeniz|                 1|                 1|  F BAKTAT|         BEBEK|     A�IZ BAKIM|AH�AP TEM�ZLEY�C�|01/02/17 08:33|01/02/17 08:33|     E|
# |    max|;31/03/17 00:00;1...|ZENNE TRASLI KAHV...|31/03/17 00:00|             502.0|           1799.0|           4278.0|                81|��rnak Subesi|��rnak|�� Anadolu|                 �|               A25|���M SEHER|        ��ECEK|��KOLATA GOFRET|       �� �AMA�IR|31/03/17 21:00|31/03/17 21:01|     K|
# +-------+--------------------+--------------------+--------------+------------------+-----------------+-----------------+------------------+-------------+------+----------+------------------+------------------+----------+--------------+---------------+-----------------+--------------+--------------+------+

# %%
rawDF.printSchema()
# Out:
# root
#  |-- ID: string (nullable = true)
#  |-- ITEMNAME: string (nullable = true)
#  |-- DATE_: string (nullable = true)
#  |-- AMOUNT: double (nullable = true)
#  |-- PRICE: double (nullable = true)
#  |-- LINENETTOTAL: double (nullable = true)
#  |-- BRANCHNR: integer (nullable = true)
#  |-- BRANCH: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- REGION: string (nullable = true)
#  |-- CLIENTCODE: string (nullable = true)
#  |-- BRANDCODE: string (nullable = true)
#  |-- BRAND: string (nullable = true)
#  |-- CATEGORY_NAME1: string (nullable = true)
#  |-- CATEGORY_NAME2: string (nullable = true)
#  |-- CATEGORY_NAME3: string (nullable = true)
#  |-- STARTDATE: string (nullable = true)
#  |-- ENDDATE: string (nullable = true)
#  |-- GENDER: string (nullable = true)

# %%
selectrawDF = rawDF.select("ITEMNAME","AMOUNT","PRICE","LINENETTOTAL","BRANCH")

# %%
selectrawDF.show()
# Out:
# +--------------------+------+-----+------------+----------------+
# |            ITEMNAME|AMOUNT|PRICE|LINENETTOTAL|          BRANCH|
# +--------------------+------+-----+------------+----------------+
# |SPRITE 1 LT LIMON...|   1.0|  2.0|         2.0|  Kocaeli Subesi|
# |           TOZ SEKER|   5.0| 2.65|       13.25|  Antalya Subesi|
# |FALIM SAKIZ 5LI NANE|   1.0|  0.4|         0.4| �stanbul Subesi|
# |FALIM SAKIZ 5LI NANE|   1.0|  0.4|         0.4| �stanbul Subesi|
# |FALIM SAKIZ 5LI C...|   1.0|  0.4|         0.4|    �zmir Subesi|
# |           TOZ SEKER|   2.0| 2.65|         5.3|   Elaz�� Subesi|
# |F NEFFIS TOZ SEKE...|   1.0|  5.6|         5.6|  Malatya Subesi|
# |           TOZ SEKER|   2.0| 2.65|         5.3| �stanbul Subesi|
# |           TOZ SEKER|   2.0| 2.65|         5.3|   Manisa Subesi|
# |F NEFFIS KESME SE...|   1.0| 2.85|        2.85|    Mu�la Subesi|
# |KENT TOPITOP DISN...|   1.0|  1.6|         1.6|      Mu� Subesi|
# |VIVIDENT CZD FRUI...|   1.0| 1.95|        1.95|    Adana Subesi|
# |LAVACHE QUIRIT UC...|   1.0| 3.45|        3.45|  Sakarya Subesi|
# |       KIRMIZI BIBER| 0.235| 4.95|        1.16|Zonguldak Subesi|
# |        CERI DOMATES|  0.76| 4.75|        3.61|Zonguldak Subesi|
# |      SALKIM DOMATES| 0.945|  5.2|        4.91|Bal�kesir Subesi|
# |             PATATES|  2.79| 2.45|        6.84|Bal�kesir Subesi|
# |      SALKIM DOMATES| 0.745|  5.2|        3.87|K�r�kkale Subesi|
# |             PATATES| 1.235| 2.45|        3.03|Gaziantep Subesi|
# |MAGGI CORBA KREMA...|   1.0| 0.85|        0.85|Gaziantep Subesi|
# +--------------------+------+-----+------------+----------------+
# only showing top 20 rows

# %%
selectrawDF.agg({"LINENETTOTAL":"sum"}).show()
# Out:
# +------------------+
# | sum(LINENETTOTAL)|
# +------------------+
# |2478409.4400002426|
# +------------------+

# %%
sumTotalByBranchDF = selectrawDF.groupBy("BRANCH").sum("LINENETTOTAL").orderBy("sum(LINENETTOTAL)", ascending=False)

# %%
rDF = sumTotalByBranchDF.withColumn("totalAmount",round("sum(LINENETTOTAL)",)).drop("sum(LINENETTOTAL)")

# %%
display(rDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BRANCH</th><th>totalAmount</th></tr></thead><tbody><tr><td>�stanbul Subesi</td><td>458485.0</td></tr><tr><td>Ankara Subesi</td><td>167002.0</td></tr><tr><td>�zmir Subesi</td><td>131799.0</td></tr><tr><td>Bursa Subesi</td><td>81149.0</td></tr><tr><td>Antalya Subesi</td><td>75283.0</td></tr><tr><td>Adana Subesi</td><td>64981.0</td></tr><tr><td>Konya Subesi</td><td>63918.0</td></tr><tr><td>�anl�urfa Subesi</td><td>58236.0</td></tr><tr><td>Kocaeli Subesi</td><td>57709.0</td></tr><tr><td>Zonguldak Subesi</td><td>57571.0</td></tr><tr><td>Gaziantep Subesi</td><td>57293.0</td></tr><tr><td>Diyarbak�r Subesi</td><td>56506.0</td></tr><tr><td>Mersin Subesi</td><td>50238.0</td></tr><tr><td>Hatay Subesi</td><td>47305.0</td></tr><tr><td>Kayseri Subesi</td><td>43516.0</td></tr><tr><td>Manisa Subesi</td><td>43348.0</td></tr><tr><td>Samsun Subesi</td><td>38537.0</td></tr><tr><td>Bal�kesir Subesi</td><td>37218.0</td></tr><tr><td>Van Subesi</td><td>35290.0</td></tr><tr><td>Kahramanmara� Subesi</td><td>32316.0</td></tr><tr><td>Ayd�n Subesi</td><td>32273.0</td></tr><tr><td>Denizli Subesi</td><td>31772.0</td></tr><tr><td>Tekirda� Subesi</td><td>29449.0</td></tr><tr><td>Sakarya Subesi</td><td>28297.0</td></tr><tr><td>Mu�la Subesi</td><td>28100.0</td></tr><tr><td>Eski�ehir Subesi</td><td>26286.0</td></tr><tr><td>Mardin Subesi</td><td>24266.0</td></tr><tr><td>Malatya Subesi</td><td>23603.0</td></tr><tr><td>Erzurum Subesi</td><td>22126.0</td></tr><tr><td>Ordu Subesi</td><td>21013.0</td></tr><tr><td>Trabzon Subesi</td><td>20979.0</td></tr><tr><td>Tokat Subesi</td><td>20106.0</td></tr><tr><td>Afyonkarahisar Subesi</td><td>19728.0</td></tr><tr><td>Osmaniye Subesi</td><td>18269.0</td></tr><tr><td>Ad�yaman Subesi</td><td>18209.0</td></tr><tr><td>Sivas Subesi</td><td>17910.0</td></tr><tr><td>A�r� Subesi</td><td>17425.0</td></tr><tr><td>K�tahya Subesi</td><td>17382.0</td></tr><tr><td>Elaz�� Subesi</td><td>17263.0</td></tr><tr><td>Batman Subesi</td><td>17018.0</td></tr><tr><td>��rnak Subesi</td><td>16759.0</td></tr><tr><td>�orum Subesi</td><td>16636.0</td></tr><tr><td>�anakkale Subesi</td><td>15241.0</td></tr><tr><td>Isparta Subesi</td><td>14623.0</td></tr><tr><td>Giresun Subesi</td><td>13961.0</td></tr><tr><td>G�m��hane Subesi</td><td>13421.0</td></tr><tr><td>Aksaray Subesi</td><td>12346.0</td></tr><tr><td>Yozgat Subesi</td><td>12207.0</td></tr><tr><td>Mu� Subesi</td><td>11999.0</td></tr><tr><td>Amasya Subesi</td><td>11235.0</td></tr><tr><td>K�rklareli Subesi</td><td>11095.0</td></tr><tr><td>Kastamonu Subesi</td><td>10992.0</td></tr><tr><td>U�ak Subesi</td><td>10515.0</td></tr><tr><td>Ni�de Subesi</td><td>10413.0</td></tr><tr><td>Bitlis Subesi</td><td>10199.0</td></tr><tr><td>Rize Subesi</td><td>9732.0</td></tr><tr><td>D�zce Subesi</td><td>9728.0</td></tr><tr><td>Edirne Subesi</td><td>9573.0</td></tr><tr><td>Siirt Subesi</td><td>9256.0</td></tr><tr><td>K�r�kkale Subesi</td><td>8855.0</td></tr><tr><td>Nev�ehir Subesi</td><td>8781.0</td></tr><tr><td>Bolu Subesi</td><td>8716.0</td></tr><tr><td>Bing�l Subesi</td><td>8603.0</td></tr><tr><td>Erzincan Subesi</td><td>8498.0</td></tr><tr><td>Karaman Subesi</td><td>7777.0</td></tr><tr><td>Hakkari Subesi</td><td>7755.0</td></tr><tr><td>Kars Subesi</td><td>7581.0</td></tr><tr><td>Burdur Subesi</td><td>7441.0</td></tr><tr><td>K�r�ehir Subesi</td><td>7357.0</td></tr><tr><td>Karab�k Subesi</td><td>7141.0</td></tr><tr><td>Yalova Subesi</td><td>6285.0</td></tr><tr><td>Bilecik Subesi</td><td>5952.0</td></tr><tr><td>Artvin Subesi</td><td>5711.0</td></tr><tr><td>I�d�r Subesi</td><td>5342.0</td></tr><tr><td>�ank�r� Subesi</td><td>5324.0</td></tr><tr><td>Sinop Subesi</td><td>5248.0</td></tr><tr><td>Bart�n Subesi</td><td>4759.0</td></tr><tr><td>Kilis Subesi</td><td>4664.0</td></tr><tr><td>Ardahan Subesi</td><td>2887.0</td></tr><tr><td>Tunceli Subesi</td><td>2587.0</td></tr><tr><td>Bayburt Subesi</td><td>2044.0</td>< ...

# %%
selectrawDF.groupBy("ITEMNAME").count().orderBy("count", ascending=False).show(truncate=False)
# Out:
# +-----------------------------+-----+
# |ITEMNAME                     |count|
# +-----------------------------+-----+
# |EKMEK 250 GR                 |9122 |
# |null                         |7175 |
# |DOMATES                      |6018 |
# |PATATES                      |5718 |
# |PORTAKAL                     |5611 |
# |TOZ SEKER                    |5242 |
# |SOGAN                        |4631 |
# |OSMANCIK PIRINC KG.          |4101 |
# |LIMON                        |4093 |
# |MUZ                          |3934 |
# |KIVIRCIK                     |3925 |
# |MAYDANOZ                     |3808 |
# |HAVUC                        |3632 |
# |S�H�RL� ELLER C�G K�FTE 200GR|3566 |
# |F NEFFIS S�T YARIM YA�LI 1 LT|3253 |
# |YERLI BADEM                  |2900 |
# |ULKER CIKOLATALI GOFRET 35GR |2692 |
# |YAHYAOGLU 15 LI YUMURTA      |2588 |
# |PORTAKAL SIKMALIK            |2561 |
# |SALKIM DOMATES               |2471 |
# +-----------------------------+-----+
# only showing top 20 rows

# %%
rawDF.select("ITEMNAME","LINENETTOTAL","CLIENTCODE").filter("LINENETTOTAL>1000").show()
# Out:
# +--------------------+------------+----------+
# |            ITEMNAME|LINENETTOTAL|CLIENTCODE|
# +--------------------+------------+----------+
# |S�H�RL� ELLER C�G...|      1439.2|    808718|
# |S�H�RL� ELLER C�G...|      1799.0|      null|
# |S�H�RL� ELLER C�G...|      1799.0|      null|
# |                null|      1304.0|       933|
# |                null|      1304.0|       933|
# |     SAMSUN 216 SOFT|      2761.0|      9010|
# |     SAMSUN 216 SOFT|      2761.0|      9010|
# |S�H�RL� ELLER C�G...|      1078.0|    237685|
# |S�H�RL� ELLER C�G...|      1078.0|    237685|
# |CANPED POLITENLI ...|      4278.0|    854889|
# |CANPED POLITENLI ...|      4278.0|    854889|
# +--------------------+------------+----------+

# %%
rawDF.select("ITEMNAME","LINENETTOTAL","CLIENTCODE").filter("LINENETTOTAL>1500 and LINENETTOTAL<5000 ").show()
# Out:
# +--------------------+------------+----------+
# |            ITEMNAME|LINENETTOTAL|CLIENTCODE|
# +--------------------+------------+----------+
# |S�H�RL� ELLER C�G...|      1799.0|      null|
# |S�H�RL� ELLER C�G...|      1799.0|      null|
# |     SAMSUN 216 SOFT|      2761.0|      9010|
# |     SAMSUN 216 SOFT|      2761.0|      9010|
# |CANPED POLITENLI ...|      4278.0|    854889|
# |CANPED POLITENLI ...|      4278.0|    854889|
# +--------------------+------------+----------+

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
